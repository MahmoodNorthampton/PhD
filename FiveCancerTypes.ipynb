# %%
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
  
import pandas as pd
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv")
# loading the iris dataset 
# X -> features, y -> label 
X = data1.drop('Class', axis=1)
y =data1['Class']
  
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) 
  
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree_predictions))
# Out:
# Accuracy: 0.8578274760383386
#               precision    recall  f1-score   support
#
#         LUAD       0.00      0.00      0.00        57
#         BRCA       0.97      0.94      0.95       279
#         KIRC       0.99      0.97      0.98       143
#         LUSC       0.48      0.92      0.63        75
#         UCEC       0.96      0.94      0.95        72
#
#     accuracy                           0.86       626
#    macro avg       0.68      0.75      0.70       626
# weighted avg       0.82      0.86      0.83       626
# C:\Users\Mahmood\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
data1
# Out:
#       'AARS'  'ABCB6'  'ABCC5'  'ABCF1'  'ABCF3'  'ABHD4'  'ABHD6'   'ABL1'  \
# 0     44.024   9.2163  11.3190   33.215   16.901   9.0313  1.11000  20.0180
# 1     29.746   9.7656  40.5400   30.169   20.047  32.2370  2.46060  17.0290
# 2     35.799   9.8848   3.8860   29.984   17.136  21.2740  1.50120  20.5980
# 3     26.490   7.0858  10.8040   23.482   17.044  14.8800  1.29910  14.9790
# 4     27.632   7.6430   3.6703   16.585   20.375  22.1750  1.55350  14.9090
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 2081  23.759  15.3940  10.8840   21.692   20.209  30.0790  0.97856  13.0020
# 2082  27.990  28.9990   8.7015   27.579   29.770  15.7450  3.75900  13.4690
# 2083  14.665  20.1960   6.7035   19.649   12.530  24.3210  2.26340   9.6429
# 2084  31.116  14.5620   9.1216   13.832   15.535  41.2790  1.04480   8.0129
# 2085  74.047  13.0040   9.4723   37.001   19.296  13.5900  0.86123  16.0300
#
#       'ACAA1'  'ACAT2'  ...  'ZMYM2'  'ZNF131'  'ZNF274'  'ZNF318'  'ZNF395'  \
# 0     16.7240  10.4940  ...  21.7060   16.3160    4.2240    8.6021   23.7620
# 1     28.3460  17.0170  ...  12.8150   10.1510    8.9148    6.7979   15.3790
# 2     25.8550  12.2760  ...  14.3450   11.2250    7.8710    7.7240   25.7620
# 3     31.2140  10.0150  ...  13.6610    9.7301    7.8048    5.0310    8.9649
# 4     54.4350  13.3920  ...  16.6500    8.5849    7.4854    5.9458    9.2053
# ...       ...      ...  ...      ...       ...       ...       ...       ...
# 2081  28.6290   6.3880  ...  10.9010    4.1881    2.4998    2.4228   10.0610
# 2082  20.5490   5.5579  ...  13.4100    8.1468    3.3909    3.6213   18.7060
# 2083  30.2490  22.1580  ...   4.3109    7.9200    2.7313    4.1689    4.4703
# 2084   8.7013   4.7778  ...   5.3034    3.7162    1.8025    1.4664    4.2094
# 2085  31.0370   7.0362  ...  12.4840    9.7306    6.7135    3.9534    9.2713
#
#       'ZNF451'  'ZNF586'  'ZNF589'  'ZW10'  Class
# 0       8.3024   1.40870    4.2956  8.7688   BRCA
# 1      11.4210   6.59970    3.8190  5.7585   BRCA
# 2       8.6288   4.10490    4.3824  5.3062   BRCA
# 3       7.9900   4.25190    3.7025  7.5005   BRCA
# 4       8.7610   4.65700    3.8279  7.9399   BRCA
# ...        ...       ...       ...     ...    ...
# 2081    3.9670   2.32320   42.4490  2.6618   UCEC
# 2082    4.2728   1.19950    3.9901  1.6652   UCEC
# 2083    3.0647   1.34150    1.8302  2.3553   UCEC
# 2084    2.6338   0.90878    1.1761  1.8913   UCEC
# 2085    4.5301   4.25300    4.3372  9.3332   UCEC
#
# [2086 rows x 972 columns]

# %%
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
    
import pandas as pd
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv")
# X -> features, y -> label 
X1 = data1.drop('Class', axis=1)
y1 =data1['Class']
  
# dividing X, y into train and test data 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1,test_size=0.3, random_state = 42) 
  
# training a linear SVM classifier 
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train1, y_train1) 
svm_predictions = svm_model_linear.predict(X_test1) 
  
# model accuracy for X_test   
accuracy = svm_model_linear.score(X_test1, y_test1) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test1, svm_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test1, svm_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test1, svm_predictions))
# Out:
# Accuracy: 0.9664536741214057
#               precision    recall  f1-score   support
#
#         LUAD       0.85      0.82      0.84        57
#         BRCA       1.00      0.99      0.99       279
#         KIRC       1.00      1.00      1.00       143
#         LUSC       0.86      0.89      0.88        75
#         UCEC       0.99      0.99      0.99        72
#
#     accuracy                           0.97       626
#    macro avg       0.94      0.94      0.94       626
# weighted avg       0.97      0.97      0.97       626

# %%
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv")
# X -> features, y -> label 
X2 = data1.drop('Class', axis=1)
y2 =data1['Class']
# dividing X, y into train and test data 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size=0.3, random_state = 42) 
  
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train2, y_train2) 
# creating a confusion matrix 
knn_predictions = knn.predict(X_test2)  
cm = confusion_matrix(y_test2, knn_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test2, knn_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test2, knn_predictions))
# Out:
# Accuracy: 0.8833865814696485
#               precision    recall  f1-score   support
#
#         LUAD       0.70      0.65      0.67        57
#         BRCA       0.96      0.92      0.94       279
#         KIRC       0.93      0.99      0.96       143
#         LUSC       0.84      0.68      0.75        75
#         UCEC       0.73      0.92      0.81        72
#
#     accuracy                           0.88       626
#    macro avg       0.83      0.83      0.83       626
# weighted avg       0.89      0.88      0.88       626

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv")
X3 = data1.drop('Class', axis=1)
y3 =data1['Class']

# dividing X, y into train and test data 
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.3,random_state = 42) 
  
# training a Naive Bayes classifier 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train3, y_train3) 
gnb_predictions = gnb.predict(X_test3) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test3, y_test3) 
print (accuracy) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test3, gnb_predictions) 
from sklearn.metrics import classification_report
print(classification_report(y_test3, gnb_predictions))
# Out:
# 0.9424920127795527
#               precision    recall  f1-score   support
#
#         LUAD       0.76      0.88      0.81        57
#         BRCA       0.99      0.96      0.97       279
#         KIRC       0.99      0.98      0.99       143
#         LUSC       0.80      0.80      0.80        75
#         UCEC       0.99      1.00      0.99        72
#
#     accuracy                           0.94       626
#    macro avg       0.91      0.92      0.91       626
# weighted avg       0.95      0.94      0.94       626

# %%
# feature selection (featurewiz) with five cancer types

# %%
from sklearn.preprocessing import LabelEncoder
# import packages 
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from featurewiz import featurewiz
import pandas as pd
data3 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv")
np.random.seed(1234)
X = data3.drop('Class', axis=1)
y =data3['Class']
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
X_scaled =  StandardScaler().fit_transform(X)
target = 'Class'
features, train = featurewiz(data3, target, corr_limit=0.7, verbose=2, sep=",",
header=0,test_data="", feature_engg="", category_encoders="")
# Out:
# Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
# Loading train data...
# Shape of your Data Set loaded: (2086, 972)
# Loading test data...
#     Filename is an empty string or file not able to be loaded
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     971 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# No GPU active on this device
#     Running XGBoost using CPU parameters
# Removing 0 columns from further processing since ID or low information variables
#     columns removed: []
#     After removing redundant variables from further processing, features left = 971
# #### Single_Label Multi_Classification Feature Selection Started ####
# Searching for highly correlated variables from 971 variables using SULOV method
# #####  SULOV : Searching for Uncorrelated List Of Variables (takes time...) ############
# There are no null values in dataset.
#     Removing (81) highly correlated variables:
#     Adding 0 categorical variables to reduced numeric variables  of 890
# ############## F E A T U R E   S E L E C T I O N  ####################
# Current number of predictors = 890
#     Finding Important Features using Boosted Trees algorithm...
#         using 890 variables...
#         using 712 variables...
#         using 534 variables...
#         using 356 variables...
#         using 178 variables...
# Selected 272 important features from your dataset
#     Time taken (in seconds) = 109
# Returning list of 272 important features and dataframe.

# %%
data4=data3[features]
data4['Class'] = y
data4
# Out:
#       'SMARCD2'   'NR3C1'  'SCYL3'     'GATA3'  'TFAP2A'  'ST3GAL5'  \
# 0        51.179  10.72100   5.0472    7.400000   24.5470    1.38320
# 1        28.718  14.71000   6.9406  184.490000   57.1040    7.97390
# 2        46.051  11.56600   7.7113  183.500000   23.0280    2.48070
# 3        43.107   7.74270   6.6163  159.790000   24.2760    2.41210
# 4        52.878  10.24100   4.6837  172.960000   26.0310    2.94390
# ...         ...       ...      ...         ...       ...        ...
# 2081     20.983   0.35593   2.7029    0.207210    7.1337    1.01710
# 2082     54.965   4.45740   2.8407    0.038647    1.3162    8.81930
# 2083     21.510   3.95880   2.5661    1.870200    1.1483    2.64510
# 2084     11.040   1.80390   1.4913    0.215710    1.3693    0.82199
# 2085     30.731   1.23090   2.2266    0.096766    4.0394    6.22110
#
#          'SOX2'  'CDCA4'  'MYCBP2'    'BCL2'  ...   'XPO7'  'WDTC1'  'TRIM13'  \
# 0      0.014911   9.7896   20.0760  15.73500  ...  15.4630   21.785    6.4785
# 1      0.007757   5.5651   16.1500  13.78900  ...  18.2230   15.396    4.1996
# 2      0.015694   5.8283   20.5420  13.44400  ...  23.2690   24.993    4.1766
# 3      1.047000   7.2046   13.5650  13.34400  ...  13.9260   20.319    6.1066
# 4      0.019026   4.5555   21.0810  11.69400  ...  10.8800   32.424    5.4828
# ...         ...      ...       ...       ...  ...      ...      ...       ...
# 2081   0.072135  18.9930    5.5900   4.92420  ...   7.0914   23.222    3.1769
# 2082  22.167000  22.0900    3.6491  16.91700  ...  19.0010   10.322    3.4279
# 2083   0.000000   4.5394    3.1567   0.70894  ...   5.6339   15.647    1.9205
# 2084   0.075094   3.4968    1.5587   0.25728  ...   4.0090   15.219    1.3985
# 2085   0.141480  26.7060   10.4090   2.77120  ...   7.7734   14.218    2.7980
#
#       'TMEM110'  'TIMM9'  'TNFRSF21'  'TBXA2R'  'USP6NL'  'UTP14A'  Class
# 0        4.7224   35.090     13.4320    1.3260    8.2799   13.1690      1
# 1        6.1391   28.575      9.4029    2.1782    4.4088    9.2724      1
# 2        6.5250   27.257      7.2031    1.5364    5.6607   12.1740      1
# 3        3.9051   32.728      4.0113    1.8406    5.9474   15.5330      1
# 4        6.2266   20.081      3.5354    1.6863    6.0786    7.6921      1
# ...         ...      ...         ...       ...       ...       ...    ...
# 2081     4.2960   16.570     28.6280    2.5040    3.9317    8.0523      4
# 2082     8.4720   16.430     15.5500    1.3499    4.9141    6.0258      4
# 2083     1.1801   15.306      7.9514    2.4951    1.2989    7.1929      4
# 2084     2.3197   10.262     12.5820    3.0753    2.3817    3.0108      4
# 2085     3.1893   21.769     22.2460    1.3244    5.1256   10.5460      4
#
# [2086 rows x 273 columns]

# %%
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
# X -> features, y -> label 
X2 = data4.drop('Class', axis=1)
y2 =data4['Class']
# dividing X, y into train and test data 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size=0.3, random_state = 42) 
  
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train2, y_train2) 
# creating a confusion matrix 
knn_predictions = knn.predict(X_test2)  
cm = confusion_matrix(y_test2, knn_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test2, knn_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test2, knn_predictions))
# Out:
# Accuracy: 0.8801916932907349
#               precision    recall  f1-score   support
#
#            0       0.82      0.63      0.71        57
#            1       0.93      0.94      0.94       279
#            2       0.93      0.98      0.95       143
#            3       0.77      0.61      0.68        75
#            4       0.74      0.92      0.82        72
#
#     accuracy                           0.88       626
#    macro avg       0.84      0.82      0.82       626
# weighted avg       0.88      0.88      0.88       626

# %%
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
    
import pandas as pd

# X -> features, y -> label 
X1 = data4.drop('Class', axis=1)
y1 =data4['Class']
  
# dividing X, y into train and test data 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1,test_size=0.3, random_state = 42) 
  
# training a linear SVM classifier 
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train1, y_train1) 
svm_predictions = svm_model_linear.predict(X_test1) 
  
# model accuracy for X_test   
accuracy = svm_model_linear.score(X_test1, y_test1) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test1, svm_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test1, svm_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test1, svm_predictions))
# Out:
# Accuracy: 0.9648562300319489
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        57
#            1       0.99      0.99      0.99       279
#            2       0.99      0.99      0.99       143
#            3       0.87      0.88      0.87        75
#            4       1.00      1.00      1.00        72
#
#     accuracy                           0.96       626
#    macro avg       0.94      0.94      0.94       626
# weighted avg       0.97      0.96      0.96       626

# %%
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
  
import pandas as pd

# loading the iris dataset 
# X -> features, y -> label 
X = data4.drop('Class', axis=1)
y =data4['Class']
  
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) 
  
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree_predictions))
# Out:
# Accuracy: 0.8578274760383386
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        57
#            1       0.97      0.94      0.95       279
#            2       0.99      0.97      0.98       143
#            3       0.48      0.92      0.63        75
#            4       0.96      0.94      0.95        72
#
#     accuracy                           0.86       626
#    macro avg       0.68      0.75      0.70       626
# weighted avg       0.82      0.86      0.83       626

# %%
#Combine gene selection

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
import pandas as pd
data2 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/GeneSelected/ReadyToUse/StructureCombine.csv")  
X1 = data2.drop('Class', axis=1)
y1 =data2['Class']

# dividing X, y into train and test data 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1,test_size=0.3, random_state = 42) 
  
# training a linear SVM classifier 
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train1, y_train1) 
svm_predictions = svm_model_linear.predict(X_test1) 
  
# model accuracy for X_test   
accuracy = svm_model_linear.score(X_test1, y_test1) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test1, svm_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test1, svm_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test1, svm_predictions))
# Out:
# Accuracy: 0.950479233226837
#               precision    recall  f1-score   support
#
#      ' LUAD'       0.78      0.82      0.80        57
#         BRCA       0.99      0.97      0.98       279
#         KIRC       0.98      1.00      0.99       143
#         LUSC       0.85      0.84      0.85        75
#         UCEC       0.99      0.97      0.98        72
#
#     accuracy                           0.95       626
#    macro avg       0.92      0.92      0.92       626
# weighted avg       0.95      0.95      0.95       626

# %%
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
import pandas as pd
data2 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/GeneSelected/ReadyToUse/StructureCombine.csv")  
X = data2.drop('Class', axis=1)
y=data2['Class']
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) 
  
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree_predictions))
# Out:
# Accuracy: 0.8466453674121406
#               precision    recall  f1-score   support
#
#      ' LUAD'       0.00      0.00      0.00        57
#         BRCA       0.97      0.94      0.95       279
#         KIRC       0.94      0.96      0.95       143
#         LUSC       0.48      0.92      0.63        75
#         UCEC       0.94      0.86      0.90        72
#
#     accuracy                           0.85       626
#    macro avg       0.67      0.74      0.69       626
# weighted avg       0.81      0.85      0.82       626
# C:\Users\Mahmood\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data2 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/GeneSelected/ReadyToUse/StructureCombine.csv")  
X3 = data2.drop('Class', axis=1)
y3 =data2['Class']
  
# dividing X, y into train and test data 
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.3,random_state = 42) 
  
# training a Naive Bayes classifier 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train3, y_train3) 
gnb_predictions = gnb.predict(X_test3) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test3, y_test3) 
print (accuracy) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test3, gnb_predictions) 
from sklearn.metrics import classification_report
print(classification_report(y_test3, gnb_predictions))
# Out:
# 0.9456869009584664
#               precision    recall  f1-score   support
#
#      ' LUAD'       0.81      0.91      0.86        57
#         BRCA       0.99      0.95      0.97       279
#         KIRC       0.99      0.99      0.99       143
#         LUSC       0.81      0.83      0.82        75
#         UCEC       0.97      0.97      0.97        72
#
#     accuracy                           0.95       626
#    macro avg       0.91      0.93      0.92       626
# weighted avg       0.95      0.95      0.95       626

# %%
# importing necessary libraries 

from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
import pandas as pd
data2 = pd.read_csv("C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/GeneSelected/ReadyToUse/StructureCombine.csv")
X2 = data2.drop('Class', axis=1)
y2 =data2['Class']
  
# dividing X, y into train and test data 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size=0.3, random_state =42) 
  
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train2, y_train2) 
  
# accuracy on X_test 
accuracy = knn.score(X_test2, y_test2) 
print (accuracy) 
  
# creating a confusion matrix 
knn_predictions = knn.predict(X_test2)  
cm = confusion_matrix(y_test2, knn_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test2, knn_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test2 ,knn_predictions))
# Out:
# 0.9041533546325878
# Accuracy: 0.9041533546325878
#               precision    recall  f1-score   support
#
#      ' LUAD'       0.67      0.74      0.70        57
#         BRCA       0.97      0.96      0.97       279
#         KIRC       0.93      0.98      0.95       143
#         LUSC       0.77      0.80      0.78        75
#         UCEC       0.98      0.76      0.86        72
#
#     accuracy                           0.90       626
#    macro avg       0.86      0.85      0.85       626
# weighted avg       0.91      0.90      0.90       626

# %%
#Stackautoencoder

# %%
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder
import pandas as pd
# define dataset
path = 'C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv'
df = pd.read_csv(path)
X= df.drop('Class', axis=1)
y= df['Class']
X = X.astype('float32')
# number of input columns
y = LabelEncoder().fit_transform(y)
n_inputs = X.shape[1]
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# define encoder
visible = Input(shape=(n_inputs,))
# encoder level 1
e = Dense(n_inputs*2)(visible)
e = BatchNormalization()(e)
e = LeakyReLU()(e)
# encoder level 2
e = Dense(n_inputs)(e)
e = BatchNormalization()(e)
e = LeakyReLU()(e)
# bottleneck
n_bottleneck = n_inputs
bottleneck = Dense(n_bottleneck)(e)
# define decoder, level 1
d = Dense(n_inputs)(bottleneck)
d = BatchNormalization()(d)
d = LeakyReLU()(d)
# decoder level 2
d = Dense(n_inputs*2)(d)
d = BatchNormalization()(d)
d = LeakyReLU()(d)
# output layer
output = Dense(n_inputs, activation='linear')(d)
# define autoencoder model
model = Model(inputs=visible, outputs=output)
# compile autoencoder model
model.compile(optimizer='adam', loss='mse')
# plot the autoencoder
plot_model(model, 'autoencoder_no_compress.png', show_shapes=True)
# fit the autoencoder model to reconstruct input
history = model.fit(X_train, X_train, epochs=200, batch_size=16, verbose=2, validation_data=(X_test,X_test))
# plot loss
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# define an encoder model (without the decoder)
encoder = Model(inputs=visible, outputs=bottleneck)
plot_model(encoder, 'encoder_no_compress.png', show_shapes=True)
# save the encoder to file
encoder.save('encoder5.h5')
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Epoch 1/200
# 92/92 - 6s - loss: 0.0522 - val_loss: 0.0131
# Epoch 2/200
# 92/92 - 6s - loss: 0.0142 - val_loss: 0.0110
# Epoch 3/200
# 92/92 - 5s - loss: 0.0133 - val_loss: 0.0171
# Epoch 4/200
# 92/92 - 6s - loss: 0.0155 - val_loss: 0.0180
# Epoch 5/200
# 92/92 - 5s - loss: 0.0125 - val_loss: 0.0133
# Epoch 6/200
# 92/92 - 5s - loss: 0.0117 - val_loss: 0.0121
# Epoch 7/200
# 92/92 - 6s - loss: 0.0105 - val_loss: 0.0109
# Epoch 8/200
# 92/92 - 5s - loss: 0.0099 - val_loss: 0.0109
# Epoch 9/200
# 92/92 - 6s - loss: 0.0094 - val_loss: 0.0101
# Epoch 10/200
# 92/92 - 6s - loss: 0.0090 - val_loss: 0.0096
# Epoch 11/200
# 92/92 - 5s - loss: 0.0087 - val_loss: 0.0099
# Epoch 12/200
# 92/92 - 6s - loss: 0.0086 - val_loss: 0.0104
# Epoch 13/200
# 92/92 - 6s - loss: 0.0084 - val_loss: 0.0101
# Epoch 14/200
# 92/92 - 5s - loss: 0.0075 - val_loss: 0.0094
# Epoch 15/200
# 92/92 - 6s - loss: 0.0078 - val_loss: 0.0104
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 168/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 169/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0033
# Epoch 170/200
# 92/92 - 6s - loss: 0.0017 - val_loss: 0.0035
# Epoch 171/200
# 92/92 - 6s - loss: 0.0017 - val_loss: 0.0031
# Epoch 172/200
# 92/92 - 6s - loss: 0.0017 - val_loss: 0.0034
# Epoch 173/200
# 92/92 - 6s - loss: 0.0018 - val_loss: 0.0033
# Epoch 174/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0031
# Epoch 175/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0032
# Epoch 176/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 177/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 178/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0033
# Epoch 179/200
# 92/92 - 5s - loss: 0.0017 - val_loss: 0.0033
# Epoch 180/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0031
# Epoch 181/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0031
# Epoch 182/200
# 92/92 - 6s - loss: 0.0015 - val_loss: 0.0031
# Epoch 183/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0032
# Epoch 184/200
# 92/92 - 5s - loss: 0.0017 - val_loss: 0.0034
# Epoch 185/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0031
# Epoch 186/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 187/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 188/200
# 92/92 - 6s - loss: 0.0015 - val_loss: 0.0031
# Epoch 189/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 190/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 191/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 192/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 193/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0034
# Epoch 194/200
# 92/92 - 6s - loss: 0.0016 - val_loss: 0.0032
# Epoch 195/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 196/200
# 92/92 - 6s - loss: 0.0015 - val_loss: 0.0031
# Epoch 197/200
# 92/92 - 5s - loss: 0.0015 - val_loss: 0.0031
# Epoch 198/200
# 92/92 - 5s - loss: 0.0017 - val_loss: 0.0035
# Epoch 199/200
# 92/92 - 5s - loss: 0.0016 - val_loss: 0.0034
# Epoch 200/200
# 92/92 - 6s - loss: 0.0015 - val_loss: 0.0033
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# evaluate logistic regression on encoded input
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
from sklearn.neighbors import KNeighborsClassifier 
import pandas as pd
import tensorflow as tf
# define dataset
path = 'C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv'
df = pd.read_csv(path)
X= df.drop('Class', axis=1)
y= df['Class']
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# load the model from file
encoder = load_model('encoder5.h5')
# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model = KNeighborsClassifier(n_neighbors = 7)
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
from sklearn.metrics import classification_report
print(classification_report(y_test, yhat))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.9424920127795527
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89        57
#            1       0.97      0.96      0.96       279
#            2       0.92      0.99      0.96       143
#            3       0.94      0.79      0.86        75
#            4       0.93      0.99      0.96        72
#
#     accuracy                           0.94       626
#    macro avg       0.93      0.92      0.92       626
# weighted avg       0.94      0.94      0.94       626

# %%
# evaluate logistic regression on encoded input
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model 
from sklearn.tree import DecisionTreeClassifier 
import pandas as pd
import tensorflow as tf
# define dataset
path = 'C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv'
df = pd.read_csv(path)
X= df.drop('Class', axis=1)
y= df['Class']
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# load the model from file
encoder = load_model('encoder5.h5')
# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model = DecisionTreeClassifier(max_depth = 2)
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
from sklearn.metrics import classification_report
print(classification_report(y_test, yhat))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.7412140575079872
#               precision    recall  f1-score   support
#
#            0       0.71      0.09      0.16        57
#            1       0.66      0.95      0.78       279
#            2       0.92      0.91      0.91       143
#            3       0.00      0.00      0.00        75
#            4       0.86      0.89      0.88        72
#
#     accuracy                           0.74       626
#    macro avg       0.63      0.57      0.54       626
# weighted avg       0.67      0.74      0.67       626
# C:\Users\Mahmood\Anaconda3\envs\Tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Mahmood\Anaconda3\envs\Tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Mahmood\Anaconda3\envs\Tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# evaluate logistic regression on encoded input
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model 
from sklearn.naive_bayes import GaussianNB 
import pandas as pd
import tensorflow as tf
# define dataset
path = 'C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv'
df = pd.read_csv(path)
X= df.drop('Class', axis=1)
y= df['Class']
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# load the model from file
encoder = load_model('encoder5.h5')
# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model = GaussianNB()
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
from sklearn.metrics import classification_report
print(classification_report(y_test, yhat))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.9073482428115016
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76        57
#            1       0.99      0.94      0.96       279
#            2       0.96      0.94      0.95       143
#            3       0.67      0.77      0.72        75
#            4       1.00      0.92      0.96        72
#
#     accuracy                           0.91       626
#    macro avg       0.86      0.88      0.87       626
# weighted avg       0.92      0.91      0.91       626

# %%
# evaluate logistic regression on encoded input
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model 
from sklearn.naive_bayes import GaussianNB 
import pandas as pd
import tensorflow as tf
from sklearn.svm import SVC 
# define dataset
path = 'C:/Users/Mahmood/Desktop/Camparsion/fiveTypes/FiveCancerTypes.csv'
df = pd.read_csv(path)
X= df.drop('Class', axis=1)
y= df['Class']
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# load the model from file
encoder = load_model('encoder5.h5')
# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model =  SVC(kernel = 'linear', C = 1)
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
from sklearn.metrics import classification_report
print(classification_report(y_test, yhat))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 0.9808306709265175
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        57
#            1       1.00      0.99      0.99       279
#            2       0.99      0.99      0.99       143
#            3       0.91      0.96      0.94        75
#            4       1.00      1.00      1.00        72
#
#     accuracy                           0.98       626
#    macro avg       0.97      0.97      0.97       626
# weighted avg       0.98      0.98      0.98       626
