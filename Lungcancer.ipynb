# %%
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
  
import pandas as pd
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/Final_Structure_Lung_squamous.csv")
# loading the iris dataset 
# X -> features, y -> label 
data1=data1.drop(['sample'], axis=1)
X = data1.drop('Class', axis=1)
y =data1['Class']
  
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) 
  
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree_predictions))
# Out:
# Accuracy: 0.9333333333333333
#                precision    recall  f1-score   support
#
#        Normal       0.86      0.92      0.89        13
# lung squamous       0.97      0.94      0.95        32
#
#      accuracy                           0.93        45
#     macro avg       0.91      0.93      0.92        45
#  weighted avg       0.94      0.93      0.93        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/Final_Structure_Lung_squamous.csv")
data3=data.drop(['sample'], axis=1)
X3 = data3.drop('Class', axis=1)
y3 =data3['Class']
  
# dividing X, y into train and test data 
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.3,random_state = 42) 
  
# training a Naive Bayes classifier 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train3, y_train3) 
gnb_predictions = gnb.predict(X_test3) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test3, y_test3) 
print (accuracy) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test3, gnb_predictions) 
from sklearn.metrics import classification_report
print(classification_report(y_test3, gnb_predictions))
# Out:
# 0.8666666666666667
#                precision    recall  f1-score   support
#
#        Normal       1.00      0.54      0.70        13
# lung squamous       0.84      1.00      0.91        32
#
#      accuracy                           0.87        45
#     macro avg       0.92      0.77      0.81        45
#  weighted avg       0.89      0.87      0.85        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/Final_Structure_Lung_squamous.csv")
data3=data.drop(['sample'], axis=1)
# X -> features, y -> label 
X2 = data3.drop('Class', axis=1)
y2 =data3['Class']
  
# dividing X, y into train and test data 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size=0.3, random_state = 42) 
  
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train2, y_train2) 
  
# accuracy on X_test 
accuracy = knn.score(X_test2, y_test2) 
print (accuracy) 
  
# creating a confusion matrix 
knn_predictions = knn.predict(X_test2)  
cm = confusion_matrix(y_test2, knn_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test2, knn_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test2, knn_predictions))
# Out:
# 1.0
# Accuracy: 1.0
#                precision    recall  f1-score   support
#
#        Normal       1.00      1.00      1.00        13
# lung squamous       1.00      1.00      1.00        32
#
#      accuracy                           1.00        45
#     macro avg       1.00      1.00      1.00        45
#  weighted avg       1.00      1.00      1.00        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/Final_Structure_Lung_squamous.csv")
data3=data.drop(['sample'], axis=1)
# X -> features, y -> label 
X1 = data3.drop('Class', axis=1)
y1 =data3['Class']
  
# dividing X, y into train and test data 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1,test_size=0.3, random_state = 42) 
  
# training a linear SVM classifier 
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train1, y_train1) 
svm_predictions = svm_model_linear.predict(X_test1) 
  
# model accuracy for X_test   
accuracy = svm_model_linear.score(X_test1, y_test1) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test1, svm_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test1, svm_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
  
import pandas as pd
data1 = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/LVQ/SelectedGenes/AllGenesSelected.csv")
# loading the iris dataset 
# X -> features, y -> label 
X = data1.drop('Class', axis=1)
y =data1['Class']
  
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) 
  
# training a DescisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier 
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test, dtree_predictions))
# Out:
# Accuracy: 1.0
#                  precision    recall  f1-score   support
#
# 'lung squamous'       1.00      1.00      1.00        32
#          Normal       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/LVQ/SelectedGenes/AllGenesSelected.csv")
# X -> features, y -> label 
X1 = data.drop('Class', axis=1)
y1 =data['Class']
  
# dividing X, y into train and test data 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1,test_size=0.3, random_state = 42) 
  
# training a linear SVM classifier 
from sklearn.svm import SVC 
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train1, y_train1) 
svm_predictions = svm_model_linear.predict(X_test1) 
  
# model accuracy for X_test   
accuracy = svm_model_linear.score(X_test1, y_test1) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test1, svm_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test1, svm_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test1, svm_predictions))
# Out:
# Accuracy: 1.0
#                  precision    recall  f1-score   support
#
# 'lung squamous'       1.00      1.00      1.00        32
#          Normal       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/LVQ/SelectedGenes/AllGenesSelected.csv")
# X -> features, y -> label 
X2 = data.drop('Class', axis=1)
y2 =data['Class']
  
# dividing X, y into train and test data 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2,test_size=0.3, random_state = 42) 
  
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train2, y_train2) 
  
# accuracy on X_test 
accuracy = knn.score(X_test2, y_test2) 
print (accuracy) 
  
# creating a confusion matrix 
knn_predictions = knn.predict(X_test2)  
cm = confusion_matrix(y_test2, knn_predictions) 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
print("Accuracy:",metrics.accuracy_score(y_test2, knn_predictions))
from sklearn.metrics import classification_report
print(classification_report(y_test2, knn_predictions))
# Out:
# 1.0
# Accuracy: 1.0
#                  precision    recall  f1-score   support
#
# 'lung squamous'       1.00      1.00      1.00        32
#          Normal       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
# importing necessary libraries 
import pandas as pd
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
data2 = pd.read_csv("C:/Users/Mahmood/Desktop/ggg/tcga_RSEM_gene_tpm/tcga_RSEM_gene_tpm/CancerTypes/Lung_Cancer/LVQ/SelectedGenes/AllGenesSelected.csv")
X3 = data2.drop('Class', axis=1)
y3 =data2['Class']
  
# dividing X, y into train and test data 
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.3,random_state = 42) 
  
# training a Naive Bayes classifier 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(X_train3, y_train3) 
gnb_predictions = gnb.predict(X_test3) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test3, y_test3) 
print (accuracy) 
  
# creating a confusion matrix 
cm = confusion_matrix(y_test3, gnb_predictions) 
from sklearn.metrics import classification_report
print(classification_report(y_test3, gnb_predictions))
# Out:
# 1.0
#                  precision    recall  f1-score   support
#
# 'lung squamous'       1.00      1.00      1.00        32
#          Normal       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
